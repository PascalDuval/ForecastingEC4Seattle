# %% [markdown]
# # Test API Notebook
# This notebook replaces `scripts/test_api.py` and shows how to verify the live prediction endpoint.

# %%
import requests

url = "http://localhost:3000/predict"
payload = {
    "log_surface": 8.5,
    "percent_electricity": 70.0,
    "has_parking": 1,
    "BuildingAge": 40,
    "surface_per_floor": 5000.0,
    "Use_Office": 1,
    "Use_Hotel": 0,
    "Use_Retail_Store": 0,
    "Use_Other": 0,
    "Use_Non_Refrigerated_Warehouse": 0,
    "Use_K12_School": 0,
    "Use_Medical_Office": 0,
    "Use_Worship_Facility": 0,
    "Use_Unknown": 0
}
response = requests.post(url, json=payload)
print("Status:", response.status_code)
print("Body:", response.json())
